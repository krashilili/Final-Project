# %%
import pandas as pd

# %%
df = pd.read_json('city_jobs.geojson')

# %%
geojson = dict()

# %%
geojson['features']=list(df['features'])

# %%
geojson['type'] = 'FeatureCollection'

# %%
geojson
# Out:
# {'features': [{'geometry': {'coordinates': [-74.0059728, 40.7127753],
#     'type': 'Point'},
#    'properties': {'City': 505,
#     'Location': 'New York, NY',
#     'city_name': 'New York',
#     'state_name': ' NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-71.0588801, 42.3600825], 'type': 'Point'},
#    'properties': {'City': 210,
#     'Location': 'Boston, MA',
#     'city_name': 'Boston',
#     'state_name': ' MA'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-80.8431267, 35.2270869], 'type': 'Point'},
#    'properties': {'City': 203,
#     'Location': 'Charlotte, NC',
#     'city_name': 'Charlotte',
#     'state_name': ' NC'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [-84.3879824, 33.7489954], 'type': 'Point'},
#    'properties': {'City': 198,
#     'Location': 'Atlanta, GA',
#     'city_name': 'Atlanta',
#     'state_name': ' GA'},
#    'type': 'Feature'},
# ...
